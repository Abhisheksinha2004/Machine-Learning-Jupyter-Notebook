# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r"C:\Users\HP\Downloads\Loan payments data.csv")
dataset.head(10)
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 5  xqd20160706     PAIDOFF        300      7       9/9/2016  9/15/2016
# 6  xqd20160007     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 7  xqd20160008     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 8  xqd20160909     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 9  xqd20160010     PAIDOFF        800     15      9/10/2016  9/24/2016
#
#      paid_off_time  past_due_days  age             education  Gender
# 0  9/14/2016 19:31            NaN   45  High School or Below    male
# ...

# %%
dataset.isnull().sum().sum()
# Out:
# 400

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# 7.2727272727272725

# %%
dataset.notnull().sum()
# Out:
# Loan_ID           500
# loan_status       500
# Principal         500
# terms             500
# effective_date    500
# due_date          500
# paid_off_time     400
# past_due_days     200
# age               500
# education         500
# Gender            500
# dtype: int64

# %%
dataset.notnull().sum().sum()
# Out:
# 5100

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.isnull().sum()
# Out:
# Loan_ID             0
# loan_status         0
# Principal           0
# terms               0
# effective_date      0
# due_date            0
# paid_off_time     100
# age                 0
# education           0
# Gender              0
# dtype: int64

# %%
dataset.shape
# Out:
# (500, 11)

# %%
dataset.drop(columns=["past_due_days"],inplace=True)

# %%
dataset.shape

# %%
dataset.dropna(inplace=True)

# %%
dataset.shape
# Out:
# (400, 10)

# %%
((500-400)/500)*100
# Out:
# 20.0

# %%
dataset.head()
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
#
#      paid_off_time  age             education  Gender
# 0  9/14/2016 19:31   45  High School or Below    male
# 1   10/7/2016 9:00   50              Bechalor  female
# 2  9/25/2016 16:58   33              Bechalor  female
# 3  9/22/2016 20:00   27               college    male
# 4  9/23/2016 21:36   28               college  female

# %%
dataset=pd.read_csv(r"C:\Users\HP\Downloads\Loan payments data.csv")
dataset.head(10)
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 5  xqd20160706     PAIDOFF        300      7       9/9/2016  9/15/2016
# 6  xqd20160007     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 7  xqd20160008     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 8  xqd20160909     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 9  xqd20160010     PAIDOFF        800     15      9/10/2016  9/24/2016
#
#      paid_off_time  past_due_days  age             education  Gender
# 0  9/14/2016 19:31            NaN   45  High School or Below    male
# ...

# %%
# dataset.fillna(188).head(10)
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 5  xqd20160706     PAIDOFF        300      7       9/9/2016  9/15/2016
# 6  xqd20160007     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 7  xqd20160008     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 8  xqd20160909     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 9  xqd20160010     PAIDOFF        800     15      9/10/2016  9/24/2016
#
#      paid_off_time  past_due_days  age             education  Gender
# 0  9/14/2016 19:31          188.0   45  High School or Below    male
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Loan_ID         500 non-null    object
#  1   loan_status     500 non-null    object
#  2   Principal       500 non-null    int64
#  3   terms           500 non-null    int64
#  4   effective_date  500 non-null    object
#  5   due_date        500 non-null    object
#  6   paid_off_time   400 non-null    object
#  7   past_due_days   200 non-null    float64
#  8   age             500 non-null    int64
#  9   education       500 non-null    object
#  10  Gender          500 non-null    object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 43.1+ KB

# %%
dataset.fillna(method="ffill",axis=1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3432\629923051.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method="ffill",axis=1)
#          Loan_ID         loan_status Principal terms effective_date  \
# 0    xqd20166231             PAIDOFF      1000    30       9/8/2016
# 1    xqd20168902             PAIDOFF      1000    30       9/8/2016
# 2    xqd20160003             PAIDOFF      1000    30       9/8/2016
# 3    xqd20160004             PAIDOFF      1000    15       9/8/2016
# 4    xqd20160005             PAIDOFF      1000    30       9/9/2016
# ..           ...                 ...       ...   ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF      1000    30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF      1000    15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF       800    15      9/12/2016
# ...

# %%
dataset["past_due_days"].fillna(dataset["past_due_days"].mode()[0],inplace=True) 
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Loan_ID         500 non-null    object
#  1   loan_status     500 non-null    object
#  2   Principal       500 non-null    int64
#  3   terms           500 non-null    int64
#  4   effective_date  500 non-null    object
#  5   due_date        500 non-null    object
#  6   paid_off_time   400 non-null    object
#  7   past_due_days   500 non-null    float64
#  8   age             500 non-null    int64
#  9   education       500 non-null    object
#  10  Gender          500 non-null    object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 43.1+ KB
# C:\Users\HP\AppData\Local\Temp\ipykernel_3432\3844422036.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset.isnull().sum()
# Out:
# Loan_ID             0
# loan_status         0
# Principal           0
# terms               0
# effective_date      0
# due_date            0
# paid_off_time     100
# past_due_days       0
# age                 0
# education           0
# Gender              0
# dtype: int64

# %%
dataset=pd.read_csv(r"C:\Users\HP\Downloads\Loan payments data.csv")
dataset.isnull().sum()
# Out:
# Loan_ID             0
# loan_status         0
# Principal           0
# terms               0
# effective_date      0
# due_date            0
# paid_off_time     100
# past_due_days     300
# age                 0
# education           0
# Gender              0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Loan_ID         500 non-null    object
#  1   loan_status     500 non-null    object
#  2   Principal       500 non-null    int64
#  3   terms           500 non-null    int64
#  4   effective_date  500 non-null    object
#  5   due_date        500 non-null    object
#  6   paid_off_time   400 non-null    object
#  7   past_due_days   200 non-null    float64
#  8   age             500 non-null    int64
#  9   education       500 non-null    object
#  10  Gender          500 non-null    object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 43.1+ KB

# %%
dataset.select_dtypes(include="int64").columns
# Out:
# Index(['Principal', 'terms', 'age'], dtype='object')

# %%
from sklearn.impute import SimpleImputer

# %%
si=SimpleImputer(strategy="mean")
ar=si.fit_transform(dataset[['Principal', 'terms', 'age']])

# %%
new_dataset=pd.DataFrame(ar,columns=dataset.select_dtypes(include="int64").columns)

# %%
new_dataset.isnull().sum()
# Out:
# Principal    0
# terms        0
# age          0
# dtype: int64

# %%
new_dataset
# Out:
#      Principal  terms   age
# 0       1000.0   30.0  45.0
# 1       1000.0   30.0  50.0
# 2       1000.0   30.0  33.0
# 3       1000.0   15.0  27.0
# 4       1000.0   30.0  28.0
# ..         ...    ...   ...
# 495     1000.0   30.0  28.0
# 496     1000.0   15.0  26.0
# 497      800.0   15.0  30.0
# 498     1000.0   30.0  38.0
# 499     1000.0   30.0  28.0
#
# [500 rows x 3 columns]

# %%
dataset=pd.read_csv(r"C:\Users\HP\Downloads\loan (1).csv")
dataset.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %%
dataset.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64
