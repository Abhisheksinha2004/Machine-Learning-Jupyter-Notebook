# %% [markdown]
# # Polynomail Logistic Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python312\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.7' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\HP\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.7' currently installed).
#   from pandas.core import (

# %%
dataset=pd.read_csv(r"C:\Users\HP\Downloads\decision_tree_data.csv")
dataset.head(3)
# Out:
#    Feature1  Feature2  Label
# 0  0.548814  0.715189      1
# 1  0.602763  0.544883      1
# 2  0.423655  0.645894      1

# %%
sns.scatterplot(x="Feature1",y="Feature2",data=dataset,hue="Label")
plt.show()

# %%
#Not linearly seperable

# %%
#firstly doing without polynomial feature

# %%
x=dataset.iloc[:,:-1]
y=dataset["Label"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 80.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=lr)

plt.show()
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Now doing it again with polynomial feature

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv(r"C:\Users\HP\Downloads\decision_tree_data.csv")
dataset.head(3)
# Out:
#    Feature1  Feature2  Label
# 0  0.548814  0.715189      1
# 1  0.602763  0.544883      1
# 2  0.423655  0.645894      1

# %%
sns.scatterplot(x="Feature1",y="Feature2",data=dataset,hue="Label")
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["Label"]

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf=PolynomialFeatures(degree=2)
pf.fit(x)
x=pd.DataFrame(pf.transform(x))

# %%
x
# Out:
#       0         1         2         3         4         5
# 0   1.0  0.548814  0.715189  0.301196  0.392506  0.511496
# 1   1.0  0.602763  0.544883  0.363324  0.328436  0.296898
# 2   1.0  0.423655  0.645894  0.179483  0.273636  0.417179
# 3   1.0  0.437587  0.891773  0.191483  0.390228  0.795259
# 4   1.0  0.963663  0.383442  0.928646  0.369508  0.147027
# ..  ...       ...       ...       ...       ...       ...
# 95  1.0  0.398221  0.209844  0.158580  0.083564  0.044034
# 96  1.0  0.186193  0.944372  0.034668  0.175836  0.891839
# 97  1.0  0.739551  0.490459  0.546935  0.362719  0.240550
# 98  1.0  0.227415  0.254356  0.051717  0.057844  0.064697
# 99  1.0  0.058029  0.434417  0.003367  0.025209  0.188718
#
# [100 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 100.0
